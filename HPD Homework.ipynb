# %%
import pandas

# %%
from urllib import urlopen
from pandas import read_csv, set_option

# %%
# HPD is a dataset of all the New York City 311 complaints related to the Department of Housing Preservation and Development 

HPD = read_csv("HPD2013.csv")
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (20,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
help(read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', dialect=None, compression=None, doublequote=True, escapechar=None, quotechar='"', quoting=0, skipinitialspace=False, lineterminator=None, header='infer', index_col=None, names=None, prefix=None, skiprows=None, skipfooter=None, skip_footer=0, na_values=None, na_fvalues=None, true_values=None, false_values=None, delimiter=None, converters=None, dtype=None, usecols=None, engine='c', delim_whitespace=False, as_recarray=False, na_filter=True, compact_ints=False, use_unsigned=False, low_memory=True, buffer_lines=None, warn_bad_lines=True, error_bad_lines=True, keep_default_na=True, thousands=None, comment=None, decimal='.', parse_dates=False, keep_date_col=False, dayfirst=False, date_parser=None, memory_map=False, nrows=None, iterator=False, chunksize=None, verbose=False, encoding=None, squeeze=False, mangle_dupe_cols=True, tupleize_cols=False, infer_datetime_format=False)
#     Read CSV (comma-separated) file into DataFrame
#
#     Also supports optionally iterating or breaking of the file
#     into chunks.
#
#     Parameters
#     ----------
#     filepath_or_buffer : string or file handle / StringIO. The string could be
#         a URL. Valid URL schemes include http, ftp, s3, and file. For file URLs, a
#         host is expected. For instance, a local file could be
#         file ://localhost/path/to/table.csv
#     sep : string, default ','
#         Delimiter to use. If sep is None, will try to automatically determine
#         this. Regular expressions are accepted.
#
#     lineterminator : string (length 1), default None
#         Character to break file into lines. Only valid with C parser
#     quotechar : string (length 1)
#         The character used to denote the start and end of a quoted item. Quoted
#         items can include the delimiter and it will be ignored.
#     quoting : int or csv.QUOTE_* instance, default None
#         Control field quoting behavior per ``csv.QUOTE_*`` constants. Use one of
#         QUOTE_MINIMAL (0), QUOTE_ALL (1), QUOTE_NONNUMERIC (2) or QUOTE_NONE (3).
#         Default (None) results in QUOTE_MINIMAL behavior.
#     skipinitialspace : boolean, default False
#         Skip spaces after delimiter
#     escapechar : string
#     dtype : Type name or dict of column -> type
#         Data type for data or columns. E.g. {'a': np.float64, 'b': np.int32}
#     compression : {'gzip', 'bz2', None}, default None
#         For on-the-fly decompression of on-disk data
#     dialect : string or csv.Dialect instance, default None
#         If None defaults to Excel dialect. Ignored if sep longer than 1 char
#         See csv.Dialect documentation for more details
#     header : int row number(s) to use as the column names, and the start of the
#         data.  Defaults to 0 if no ``names`` passed, otherwise ``None``. Explicitly
#         pass ``header=0`` to be able to replace existing names. The header can be
#         a list of integers that specify row locations for a multi-index on the
#         columns E.g. [0,1,3]. Intervening rows that are not specified will be
#         skipped. (E.g. 2 in this example are skipped)
#     skiprows : list-like or integer
#         Row numbers to skip (0-indexed) or number of rows to skip (int)
#         at the start of the file
#     index_col : int or sequence or False, default None
#         Column to use as the row labels of the DataFrame. If a sequence is given, a
#         MultiIndex is used. If you have a malformed file with delimiters at the end
#         of each line, you might consider index_col=False to force pandas to _not_
#         use the first column as the index (row names)
#     names : array-like
#         List of column names to use. If file contains no header row, then you
#         should explicitly pass header=None
#     prefix : string or None (default)
#         Prefix to add to column numbers when no header, e.g 'X' for X0, X1, ...
#     na_values : list-like or dict, default None
#         Additional strings to recognize as NA/NaN. If dict passed, specific
#         per-column NA values
#     true_values : list
#         Values to consider as True
#     false_values : list
#         Values to consider as False
#     keep_default_na : bool, default True
#         If na_values are specified and keep_default_na is False the default NaN
#         values are overridden, otherwise they're appended to
#     parse_dates : boolean, list of ints or names, list of lists, or dict
#         If True -> try parsing the index.
#         If [1, 2, 3] -> try parsing columns 1, 2, 3 each as a separate date column.
#         If [[1, 3]] -> combine columns 1 and 3 and parse as a single date column.
#         {'foo' : [1, 3]} -> parse columns 1, 3 as date and call result 'foo'
#         A fast-path exists for iso8601-formatted dates.
#     keep_date_col : boolean, default False
#         If True and parse_dates specifies combining multiple columns then
#         keep the original columns.
#     date_parser : function
#         Function to use for converting a sequence of string columns to an
#         array of datetime instances. The default uses dateutil.parser.parser
#         to do the conversion.
#     dayfirst : boolean, default False
#         DD/MM format dates, international and European format
#     thousands : str, default None
#         Thousands separator
#     comment : str, default None
#         Indicates remainder of line should not be parsed
#         Does not support line commenting (will return empty line)
#     decimal : str, default '.'
#         Character to recognize as decimal point. E.g. use ',' for European data
#     nrows : int, default None
#         Number of rows of file to read. Useful for reading pieces of large files
#     iterator : boolean, default False
#         Return TextFileReader object
#     chunksize : int, default None
#         Return TextFileReader object for iteration
#     skipfooter : int, default 0
#         Number of line at bottom of file to skip
#     converters : dict. optional
#         Dict of functions for converting values in certain columns. Keys can either
#         be integers or column labels
#     verbose : boolean, default False
#         Indicate number of NA values placed in non-numeric columns
#     delimiter : string, default None
#         Alternative argument name for sep. Regular expressions are accepted.
#     encoding : string, default None
#         Encoding to use for UTF when reading/writing (ex. 'utf-8')
#     squeeze : boolean, default False
#         If the parsed data only contains one column then return a Series
#     na_filter: boolean, default True
#         Detect missing value markers (empty strings and the value of na_values). In
#         data without any NAs, passing na_filter=False can improve the performance
#         of reading a large file
#     usecols : array-like
#         Return a subset of the columns.
#         Results in much faster parsing time and lower memory usage.
#     mangle_dupe_cols: boolean, default True
#         Duplicate columns will be specified as 'X.0'...'X.N', rather than 'X'...'X'
#     tupleize_cols: boolean, default False
#         Leave a list of tuples on columns as is (default is to convert to
#         a Multi Index on the columns)
#     error_bad_lines: boolean, default True
#         Lines with too many fields (e.g. a csv line with too many commas) will by
#         default cause an exception to be raised, and no DataFrame will be returned.
#         If False, then these "bad lines" will dropped from the DataFrame that is
#         returned. (Only valid with C parser).
#     warn_bad_lines: boolean, default True
#         If error_bad_lines is False, and warn_bad_lines is True, a warning for each
#         "bad line" will be output. (Only valid with C parser).
#     infer_datetime_format : boolean, default False
#         If True and parse_dates is enabled for a column, attempt to infer
#         the datetime format to speed up the processing
#
#     Returns
#     -------
#     result : DataFrame or TextParser

# %%
#let's look at the data

HPD.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    27023049  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 1    27022947  12/31/2013 12:00:00 AM  12/31/2013 12:00:00 AM    HPD
# 2    27018891  12/31/2013 12:00:00 AM                     NaN    HPD
# 3    27019814  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 4    27018953  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
#
#                                          Agency Name Complaint Type  \
# 0  Department of Housing Preservation and Develop...        HEATING
# 1  Department of Housing Preservation and Develop...        HEATING
# 2  Department of Housing Preservation and Develop...        HEATING
# 3  Department of Housing Preservation and Develop...        HEATING
# 4  Department of Housing Preservation and Develop...        HEATING
#
#   Descriptor         Location Type  Incident Zip      Incident Address  \
# 0       HEAT  RESIDENTIAL BUILDING         10471   221 WEST 242 STREET
# 1       HEAT  RESIDENTIAL BUILDING         10462  2160 MATTHEWS AVENUE
# 2       HEAT  RESIDENTIAL BUILDING         11215    297 GARFIELD PLACE
# 3       HEAT  RESIDENTIAL BUILDING         11213   952 ST MARKS AVENUE
# 4       HEAT  RESIDENTIAL BUILDING         10034      60 SEAMAN AVENUE
#
#        Street Name   Cross Street 1             Cross Street 2  \
# 0  WEST 242 STREET     NYCTA SUBWAY  MANHATTAN COLLEGE PARKWAY
# 1  MATTHEWS AVENUE     LYDIG AVENUE             PELHAM PARKWAY
# 2   GARFIELD PLACE         8 AVENUE         PROSPECT PARK WEST
# 3  ST MARKS AVENUE  KINGSTON AVENUE              ALBANY AVENUE
# 4    SEAMAN AVENUE   ACADEMY STREET            WEST 204 STREET
#
#    Intersection Street 1  Intersection Street 2 Address Type      City  \
# 0                    NaN                    NaN      ADDRESS     BRONX
# 1                    NaN                    NaN      ADDRESS     BRONX
# 2                    NaN                    NaN      ADDRESS  BROOKLYN
# 3                    NaN                    NaN      ADDRESS  BROOKLYN
# 4                    NaN                    NaN      ADDRESS  NEW YORK
#
#    Landmark  Facility Type  Status
# 0       NaN            NaN  Closed ...
# 1       NaN            NaN  Closed ...
# 2       NaN            NaN    Open ...
# 3       NaN            NaN  Closed ...
# 4       NaN            NaN  Closed ...
#
# [5 rows x 52 columns]

# %%
print "HPD has", HPD.shape[0], "rows and",HPD.shape[1],"columns"
# Out:
# HPD has 574319 rows and 52 columns

# %%
# Initially, I was hoping NYCHA buildings would be included, but it seems to be only residential

HPD["Location Type"].value_counts()
# Out:
# RESIDENTIAL BUILDING    574304
# dtype: int64

# %%
#let's have a look at the distribution of complaints ber borough. Unsurprisingly, Brooklyn has the most complaints. 

HPD["Borough"].value_counts().plot(kind="barh")

# %%
# Let's look at the type of complaints. Heating is the most common one by far with 201781 requests. Nobody requests HPD Literature. 

HPD["Complaint Type"].value_counts()
# Out:
# HEATING                   201781
# GENERAL CONSTRUCTION      112897
# PLUMBING                   86136
# PAINT - PLASTER            78482
# NONCONST                   53563
# ELECTRIC                   34908
# APPLIANCE                   5492
# CONSTRUCTION                1029
# STRUCTURAL                    16
# HPD Literature Request        15
# dtype: int64

# %%
# Let's see how the complaints are distributed per borough. The Bronx has the most heat related complaints, 
#even though it's not the most populous borough and Brooklyn has more complaints overall. 
# It's a story!

from pandas import crosstab
complaints = crosstab(HPD["Borough"],HPD["Complaint Type"])
complaints
# Out:
# Complaint Type  APPLIANCE  CONSTRUCTION  ELECTRIC  GENERAL CONSTRUCTION  \
# Borough
# BRONX                1705           276      9772                 35208
# BROOKLYN             1944           339     13550                 41868
# MANHATTAN             957           204      5607                 20235
# QUEENS                771           173      5133                 13028
# STATEN ISLAND         115            37       846                  2558
# Unspecified             0             0         0                     0
#
# Complaint Type  HEATING  HPD Literature Request  NONCONST  PAINT - PLASTER  \
# Borough
# BRONX             67306                       0     15106            24902
# BROOKLYN          60721                       0     20161            28742
# MANHATTAN         47118                       0      9901            15072
# QUEENS            24774                       0      7212             8406
# STATEN ISLAND      1862                       0      1183             1360
# Unspecified           0                      15         0                0
#
# Complaint Type  PLUMBING  STRUCTURAL
# Borough
# BRONX              26110           4
# BROOKLYN           32247           4
# MANHATTAN          15516           3
# QUEENS             10489           4
# STATEN ISLAND       1774           1
# Unspecified            0           0
#
# [6 rows x 10 columns]

# %%
#Here it tried out some mapping stuff, which didn't work. But let's keep the code for later. 

# from urllib import urlretrieve
# url = "http://www.nyc.gov/html/dcp/download/bytes/nybb_13a.zip"
# urlretrieve(url,"nybb_13a.zip")
# Out:
# ('nybb_13a.zip', <httplib.HTTPMessage instance at 0x62bdb48>)

# %%
# %%script bash
# unzip nybb_13a.zip
# Out:
# Archive:  nybb_13a.zip
# replace nybb_13a/nybb.shp? [y]es, [n]o, [A]ll, [N]one, [r]ename:  NULL
# (EOF or read error, treating as "[N]one" ...)

# %%
# from geopandas import GeoDataFrame

# boros = GeoDataFrame.from_file('nybb_13a/nybb.shp')
# boros
# Out:
# /usr/local/lib/python2.7/dist-packages/setuptools-3.1-py2.7.egg/pkg_resources.py:1031: UserWarning: /home/ubuntu/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).
#    BoroCode       BoroName    Shape_Area     Shape_Leng  \
# 0         5  Staten Island  1.623853e+09  330385.036974
# 1         4         Queens  3.049947e+09  861038.479299
# 2         3       Brooklyn  1.959432e+09  726568.946340
# 3         1      Manhattan  6.364422e+08  358532.956418
# 4         2          Bronx  1.186804e+09  464517.890553
#
#                                             geometry
# 0  (POLYGON ((970217.0223999023 145643.3322143555...
# 1  (POLYGON ((1029606.076599121 156073.8142089844...
# 2  (POLYGON ((1021176.479003906 151374.7969970703...
# 3  (POLYGON ((981219.0557861328 188655.3157958984...
# 4  (POLYGON ((1012821.805786133 229228.2645874023...
#
# [5 rows x 5 columns]

# %%
# boros["fake"] = [100,10,5,2,100]

# figure(figsize=[10,10])
# boros.plot("Shape_Area",colormap="Blues")
# show()

# %%
#from pandas import merge
#help(merge)
# Out:
# Help on function merge in module pandas.tools.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True)
#     Merge DataFrame objects by performing a database-style join operation by
#     columns or indexes.
#
#     If joining columns on columns, the DataFrame indexes *will be
#     ignored*. Otherwise if joining indexes on indexes or indexes on a column or
#     columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         * left: use only keys from left frame (SQL: left outer join)
#         * right: use only keys from right frame (SQL: right outer join)
#         * outer: use union of keys from both frames (SQL: full outer join)
#         * inner: use intersection of keys from both frames (SQL: inner join)
#     on : label or list
#         Field names to join on. Must be found in both DataFrames. If on is
#         None and not merging on indexes, then it merges on the intersection of
#         the columns by default.
#     left_on : label or list, or array-like
#         Field names to join on in left DataFrame. Can be a vector or list of
#         vectors of the length of the DataFrame to use a particular vector as
#         the join key instead of columns
#     right_on : label or list, or array-like
#         Field names to join on in right DataFrame or vector/list of vectors per
#         left_on docs
#     left_index : boolean, default False
#         Use the index from the left DataFrame as the join key(s). If it is a
#         MultiIndex, the number of keys in the other DataFrame (either the index
#         or a number of columns) must match the number of levels
#     right_index : boolean, default False
#         Use the index from the right DataFrame as the join key. Same caveats as
#         left_index
#     sort : boolean, default False
#         Sort the join keys lexicographically in the result DataFrame
#     suffixes : 2-length sequence (tuple, list, ...)
#         Suffix to apply to overlapping column names in the left and right
#         side, respectively
#     copy : boolean, default True
#         If False, do not copy data unnecessarily
#
#     Examples
#     --------
#
#     >>> A              >>> B
#         lkey value         rkey value
#     0   foo  1         0   foo  5
#     1   bar  2         1   bar  6
#     2   baz  3         2   qux  7
#     3   foo  4         3   bar  8
#
#     >>> merge(A, B, left_on='lkey', right_on='rkey', how='outer')
#        lkey  value_x  rkey  value_y
#     0  bar   2        bar   6
#     1  bar   2        bar   8
#     2  baz   3        NaN   NaN
#     3  foo   1        foo   5
#     4  foo   4        foo   5
#     5  NaN   NaN      qux   7
#
#     Returns
#     -------
#     merged : DataFrame

# %%
#merge(complaints, boros, left_on="Borough", right_on="BoroName")

# %%
#HPD["Complaint Type"].is("HEATING")

# %%
#Let's look at our original dataset again

HPD.describe()
# Out:
#             Unique Key   Incident Zip  Intersection Street 1  \
# count    574319.000000  554520.000000                      0
# mean   25815173.432331   10750.755415                    NaN
# std      736313.785630     510.855006                    NaN
# min    24697293.000000   10001.000000                    NaN
# 25%    25115184.500000   10453.000000                    NaN
# 50%    25771288.000000   10469.000000                    NaN
# 75%    26552901.500000   11224.000000                    NaN
# max    27024778.000000   11697.000000                    NaN
#
#        Intersection Street 2  Landmark  Facility Type  \
# count                      0         0              0
# mean                     NaN       NaN            NaN
# std                      NaN       NaN            NaN
# min                      NaN       NaN            NaN
# 25%                      NaN       NaN            NaN
# 50%                      NaN       NaN            NaN
# 75%                      NaN       NaN            NaN
# max                      NaN       NaN            NaN
#
#        X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# count               554521.000000               554521.000000
# mean               1006468.803930               214075.672155
# std                  15555.455266                33294.761218
# min                 914072.000000               121329.000000
# 25%                 997651.000000               183721.000000
# 50%                1005686.000000               214588.000000
# 75%                1014382.000000               245524.000000
# max                1067116.000000               271876.000000
#
#        School or Citywide Complaint  Vehicle Type  Taxi Company Borough  \
# count                             0             0                     0
# mean                            NaN           NaN                   NaN
# std                             NaN           NaN                   NaN
# min                             NaN           NaN                   NaN
# 25%                             NaN           NaN                   NaN
# 50%                             NaN           NaN                   NaN
# 75%                             NaN           NaN                   NaN
# max                             NaN           NaN                   NaN
#
#        Taxi Pick Up Location  Bridge Highway Name  Bridge Highway Direction  \
# count                      0                    0                         0
# mean                     NaN                  NaN                       NaN
# std                      NaN                  NaN                       NaN
# min                      NaN                  NaN                       NaN
# 25%                      NaN                  NaN                       NaN
# 50%                      NaN                  NaN                       NaN
# 75%                      NaN                  NaN                       NaN
# max                      NaN                  NaN                       NaN
#
#        Road Ramp  Bridge Highway Segment  Garage Lot Name  Ferry Direction  \
# count          0                       0                0                0
# mean         NaN                     NaN              NaN              NaN
# std          NaN                     NaN              NaN              NaN
# min          NaN                     NaN              NaN              NaN
# 25%          NaN                     NaN              NaN              NaN
# 50%          NaN                     NaN              NaN              NaN
# 75%          NaN                     NaN              NaN              NaN
# max          NaN                     NaN              NaN              NaN
#
#        Ferry Terminal Name       Latitude
# count                    0  558540.000000 ...
# mean                   NaN      40.754313 ...
# std                    NaN       0.091404 ...
# min                    NaN      40.499440 ...
# 25%                    NaN      40.670921 ...
# 50%                    NaN      40.755940 ...
# 75%                    NaN      40.840608 ...
# max                    NaN      40.912869 ...
#
# [8 rows x 21 columns]

# %%
# Let's subset the heating related complaints

HEAT = HPD[HPD["Complaint Type"]=="HEATING"]

# %%
#Let's have look!
HEAT
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     27023049  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 1     27022947  12/31/2013 12:00:00 AM  12/31/2013 12:00:00 AM    HPD
# 2     27018891  12/31/2013 12:00:00 AM                     NaN    HPD
# 3     27019814  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 4     27018953  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 5     27022182  12/31/2013 12:00:00 AM                     NaN    HPD
# 6     27022180  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 7     27023038  12/31/2013 12:00:00 AM                     NaN    HPD
# 8     27022146  12/31/2013 12:00:00 AM  01/01/2014 12:00:00 AM    HPD
# 9     27022149  12/31/2013 12:00:00 AM                     NaN    HPD
# 10    27022178  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 11    27022175  12/31/2013 12:00:00 AM                     NaN    HPD
# 12    27022241  12/31/2013 12:00:00 AM                     NaN    HPD
# 13    27024730  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 14    27023086  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 16    27022202  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 17    27022201  12/31/2013 12:00:00 AM                     NaN    HPD
# 18    27022232  12/31/2013 12:00:00 AM                     NaN    HPD
# 19    27022187  12/31/2013 12:00:00 AM  01/01/2014 12:00:00 AM    HPD
# 20    27023080  12/31/2013 12:00:00 AM                     NaN    HPD
# 21    27024702  12/31/2013 12:00:00 AM  12/31/2013 12:00:00 AM    HPD
# 22    27022265  12/31/2013 12:00:00 AM                     NaN    HPD
# 23    27022252  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 24    27022243  12/31/2013 12:00:00 AM                     NaN    HPD
# 25    27020510  12/31/2013 12:00:00 AM                     NaN    HPD
# 26    27024699  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 27    27020490  12/31/2013 12:00:00 AM                     NaN    HPD
# 28    27020496  12/31/2013 12:00:00 AM                     NaN    HPD
# 29    27024697  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 30    27024687  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 33    27024758  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 36    27023036  12/31/2013 12:00:00 AM                     NaN    HPD
# 37    27022970  12/31/2013 12:00:00 AM                     NaN    HPD
# 38    27020540  12/31/2013 12:00:00 AM                     NaN    HPD
# 39    27020541  12/31/2013 12:00:00 AM                     NaN    HPD
# 40    27023033  12/31/2013 12:00:00 AM                     NaN    HPD
# 41    27020542  12/31/2013 12:00:00 AM  01/04/2014 12:00:00 AM    HPD
# 42    27023017  12/31/2013 12:00:00 AM  01/04/2014 12:00:00 AM    HPD
# 43    27020573  12/31/2013 12:00:00 AM                     NaN    HPD
# 44    27022992  12/31/2013 12:00:00 AM  01/04/2014 12:00:00 AM    HPD
# 45    27020583  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 46    27020575  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 48    27022143  12/31/2013 12:00:00 AM  12/31/2013 12:00:00 AM    HPD
# 50    27023073  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 51    27021312  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 52    27021398  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 53    27021383  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 54    27023003  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 58    27023088  12/31/2013 12:00:00 AM                     NaN    HPD
# 60    27023072  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 61    27024622  12/31/2013 12:00:00 AM                     NaN    HPD
# 62    27023039  12/31/2013 12:00:00 AM                     NaN    HPD
# 63    27024628  12/31/2013 12:00:00 AM  01/04/2014 12:00:00 AM    HPD
# 64    27024627  12/31/2013 12:00:00 AM  12/31/2013 12:00:00 AM    HPD
# 65    27024641  12/31/2013 12:00:00 AM                     NaN    HPD
# 67    27024670  12/31/2013 12:00:00 AM  01/02/2014 12:00:00 AM    HPD
# 68    27024667  12/31/2013 12:00:00 AM                     NaN    HPD
# 70    27024688  12/31/2013 12:00:00 AM                     NaN    HPD
# 71    27024680  12/31/2013 12:00:00 AM  01/03/2014 12:00:00 AM    HPD
# 72    27024755  12/31/2013 12:00:00 AM                     NaN    HPD
#            ...                     ...                     ...    ...
#
#                                           Agency Name Complaint Type  \
# 0   Department of Housing Preservation and Develop...        HEATING
# 1   Department of Housing Preservation and Develop...        HEATING
# 2   Department of Housing Preservation and Develop...        HEATING
# 3   Department of Housing Preservation and Develop...        HEATING
# 4   Department of Housing Preservation and Develop...        HEATING
# 5   Department of Housing Preservation and Develop...        HEATING
# 6   Department of Housing Preservation and Develop...        HEATING
# 7   Department of Housing Preservation and Develop...        HEATING
# 8   Department of Housing Preservation and Develop...        HEATING
# 9   Department of Housing Preservation and Develop...        HEATING
# 10  Department of Housing Preservation and Develop...        HEATING
# 11  Department of Housing Preservation and Develop...        HEATING
# 12  Department of Housing Preservation and Develop...        HEATING
# 13  Department of Housing Preservation and Develop...        HEATING
# 14  Department of Housing Preservation and Develop...        HEATING
# 16  Department of Housing Preservation and Develop...        HEATING
# 17  Department of Housing Preservation and Develop...        HEATING
# 18  Department of Housing Preservation and Develop...        HEATING
# 19  Department of Housing Preservation and Develop...        HEATING
# 20  Department of Housing Preservation and Develop...        HEATING
# 21  Department of Housing Preservation and Develop...        HEATING
# 22  Department of Housing Preservation and Develop...        HEATING
# 23  Department of Housing Preservation and Develop...        HEATING
# 24  Department of Housing Preservation and Develop...        HEATING
# 25  Department of Housing Preservation and Develop...        HEATING
# 26  Department of Housing Preservation and Develop...        HEATING
# 27  Department of Housing Preservation and Develop...        HEATING
# 28  Department of Housing Preservation and Develop...        HEATING
# 29  Department of Housing Preservation and Develop...        HEATING
# 30  Department of Housing Preservation and Develop...        HEATING
# 33  Department of Housing Preservation and Develop...        HEATING
# 36  Department of Housing Preservation and Develop...        HEATING
# 37  Department of Housing Preservation and Develop...        HEATING
# 38  Department of Housing Preservation and Develop...        HEATING
# 39  Department of Housing Preservation and Develop...        HEATING
# 40  Department of Housing Preservation and Develop...        HEATING
# 41  Department of Housing Preservation and Develop...        HEATING
# 42  Department of Housing Preservation and Develop...        HEATING
# 43  Department of Housing Preservation and Develop...        HEATING
# 44  Department of Housing Preservation and Develop...        HEATING
# 45  Department of Housing Preservation and Develop...        HEATING
# 46  Department of Housing Preservation and Develop...        HEATING
# 48  Department of Housing Preservation and Develop...        HEATING
# 50  Department of Housing Preservation and Develop...        HEATING
# 51  Department of Housing Preservation and Develop...        HEATING
# 52  Department of Housing Preservation and Develop...        HEATING
# 53  Department of Housing Preservation and Develop...        HEATING
# 54  Department of Housing Preservation and Develop...        HEATING
# 58  Department of Housing Preservation and Develop...        HEATING
# 60  Department of Housing Preservation and Develop...        HEATING
# 61  Department of Housing Preservation and Develop...        HEATING
# 62  Department of Housing Preservation and Develop...        HEATING
# 63  Department of Housing Preservation and Develop...        HEATING
# 64  Department of Housing Preservation and Develop...        HEATING
# 65  Department of Housing Preservation and Develop...        HEATING
# 67  Department of Housing Preservation and Develop...        HEATING
# 68  Department of Housing Preservation and Develop...        HEATING
# 70  Department of Housing Preservation and Develop...        HEATING
# 71  Department of Housing Preservation and Develop...        HEATING
# 72  Department of Housing Preservation and Develop...        HEATING
#                                                   ...            ...
#
#    Descriptor         Location Type  Incident Zip          Incident Address  \
# 0        HEAT  RESIDENTIAL BUILDING         10471       221 WEST 242 STREET
# 1        HEAT  RESIDENTIAL BUILDING         10462      2160 MATTHEWS AVENUE
# 2        HEAT  RESIDENTIAL BUILDING         11215        297 GARFIELD PLACE
# 3        HEAT  RESIDENTIAL BUILDING         11213       952 ST MARKS AVENUE
# 4        HEAT  RESIDENTIAL BUILDING         10034          60 SEAMAN AVENUE
# 5        HEAT  RESIDENTIAL BUILDING         11221         466 PUTNAM AVENUE
# 6        HEAT  RESIDENTIAL BUILDING         10463        3810 BAILEY AVENUE
# 7        HEAT  RESIDENTIAL BUILDING         11221         20 MENAHAN STREET
# 8        HEAT  RESIDENTIAL BUILDING         10463        3840 ORLOFF AVENUE
# 9        HEAT  RESIDENTIAL BUILDING         11692       338 BEACH 66 STREET
# 10       HEAT  RESIDENTIAL BUILDING         10463        3810 BAILEY AVENUE
# 11       HEAT  RESIDENTIAL BUILDING         11226          1 ST PAULS COURT
# 12       HEAT  RESIDENTIAL BUILDING         11234             5116 AVENUE L
# 13       HEAT  RESIDENTIAL BUILDING         10456      1220 GRAND CONCOURSE
# 14       HEAT  RESIDENTIAL BUILDING         10452      1235 GRAND CONCOURSE
# 16       HEAT  RESIDENTIAL BUILDING         10452       155 WEST 162 STREET
# 17       HEAT  RESIDENTIAL BUILDING         11106           31-36 14 STREET
# 18       HEAT  RESIDENTIAL BUILDING         11203        729 EAST 42 STREET
# 19       HEAT  RESIDENTIAL BUILDING         10462   1381 CASTLE HILL AVENUE
# 20       HEAT  RESIDENTIAL BUILDING         11213       1387 ST JOHNS PLACE
# 21       HEAT  RESIDENTIAL BUILDING         10467        2801 BARKER AVENUE
# 22       HEAT  RESIDENTIAL BUILDING         11234       1199 EAST 53 STREET
# 23       HEAT  RESIDENTIAL BUILDING         10463        3810 BAILEY AVENUE
# 24       HEAT  RESIDENTIAL BUILDING         10454       459 EAST 135 STREET
# 25       HEAT  RESIDENTIAL BUILDING         10040        45 FAIRVIEW AVENUE
# 26       HEAT  RESIDENTIAL BUILDING         10033  370 FT WASHINGTON AVENUE
# 27       HEAT  RESIDENTIAL BUILDING         11213       970 ST MARKS AVENUE
# 28       HEAT  RESIDENTIAL BUILDING         10035       112 EAST 128 STREET
# 29       HEAT  RESIDENTIAL BUILDING         10458        2979 MARION AVENUE
# 30       HEAT  RESIDENTIAL BUILDING         10452        1075 GERARD AVENUE
# 33       HEAT  RESIDENTIAL BUILDING         11207        64 WILLIAMS AVENUE
# 36       HEAT  RESIDENTIAL BUILDING         10468      2593 GRAND CONCOURSE
# 37       HEAT  RESIDENTIAL BUILDING         11223              576 AVENUE Z
# 38       HEAT  RESIDENTIAL BUILDING         10456        1102 FOREST AVENUE
# 39       HEAT  RESIDENTIAL BUILDING         10026      254 MANHATTAN AVENUE
# 40       HEAT  RESIDENTIAL BUILDING         10469     3338 EASTCHESTER ROAD
# 41       HEAT  RESIDENTIAL BUILDING         10468       2682 CRESTON AVENUE
# 42       HEAT  RESIDENTIAL BUILDING         10027        55 WEST 129 STREET
# 43       HEAT  RESIDENTIAL BUILDING         10001        208 WEST 30 STREET
# 44       HEAT  RESIDENTIAL BUILDING         11235       2729 EAST 28 STREET
# 45       HEAT  RESIDENTIAL BUILDING         10031       2 ST NICHOLAS PLACE
# 46       HEAT  RESIDENTIAL BUILDING         11236      1074 EAST 105 STREET
# 48       HEAT  RESIDENTIAL BUILDING         11223              576 AVENUE Z
# 50       HEAT  RESIDENTIAL BUILDING         10039       208 WEST 151 STREET
# 51       HEAT  RESIDENTIAL BUILDING         11215              300 8 AVENUE
# 52       HEAT  RESIDENTIAL BUILDING         11208        415 LINCOLN AVENUE
# 53       HEAT  RESIDENTIAL BUILDING         10032       541 WEST 158 STREET
# 54       HEAT  RESIDENTIAL BUILDING         10463        3810 BAILEY AVENUE
# 58       HEAT  RESIDENTIAL BUILDING         11226        578 EAST 17 STREET
# 60       HEAT  RESIDENTIAL BUILDING         10027         21 CONVENT AVENUE
# 61       HEAT  RESIDENTIAL BUILDING         10466     4128 CARPENTER AVENUE
# 62       HEAT  RESIDENTIAL BUILDING         11236       1108 EAST 82 STREET
# 63       HEAT  RESIDENTIAL BUILDING         10027             2411 8 AVENUE
# 64       HEAT  RESIDENTIAL BUILDING         10040           34 ARDEN STREET
# 65       HEAT  RESIDENTIAL BUILDING         11210       1022 EAST 36 STREET
# 67       HEAT  RESIDENTIAL BUILDING         10463        3810 BAILEY AVENUE
# 68       HEAT  RESIDENTIAL BUILDING         10460    1490 CROTONA PARK EAST
# 70       HEAT  RESIDENTIAL BUILDING         10035       112 EAST 128 STREET
# 71       HEAT  RESIDENTIAL BUILDING         10472       1025 BOYNTON AVENUE
# 72       HEAT  RESIDENTIAL BUILDING         11207       224 SCHAEFER STREET
#           ...                   ...           ...                       ...
#
#              Street Name              Cross Street 1  \
# 0        WEST 242 STREET                NYCTA SUBWAY
# 1        MATTHEWS AVENUE                LYDIG AVENUE
# 2         GARFIELD PLACE                    8 AVENUE
# 3        ST MARKS AVENUE             KINGSTON AVENUE
# 4          SEAMAN AVENUE              ACADEMY STREET
# 5          PUTNAM AVENUE             TOMPKINS AVENUE
# 6          BAILEY AVENUE             WEST 238 STREET
# 7         MENAHAN STREET             BUSHWICK AVENUE
# 8          ORLOFF AVENUE                CANNON PLACE
# 9        BEACH 66 STREET                    DEAD END
# 10         BAILEY AVENUE             WEST 238 STREET
# 11        ST PAULS COURT              ST PAULS PLACE
# 12              AVENUE L              EAST 51 STREET
# 13       GRAND CONCOURSE             EAST 167 STREET
# 14       GRAND CONCOURSE             EAST 167 STREET
# 16       WEST 162 STREET                OGDEN AVENUE
# 17             14 STREET                     31 ROAD
# 18        EAST 42 STREET               FOSTER AVENUE
# 19    CASTLE HILL AVENUE                 LYON AVENUE
# 20        ST JOHNS PLACE          SCHENECTADY AVENUE
# 21         BARKER AVENUE              BRITTON STREET
# 22        EAST 53 STREET                    AVENUE I
# 23         BAILEY AVENUE             WEST 238 STREET
# 24       EAST 135 STREET  MAJOR DEEGAN EXPWY ET 2 NB
# 25       FAIRVIEW AVENUE                        BEND
# 26  FT WASHINGTON AVENUE             WEST 176 STREET
# 27       ST MARKS AVENUE             KINGSTON AVENUE
# 28       EAST 128 STREET                 PARK AVENUE
# 29         MARION AVENUE      BEDFORD PARK BOULEVARD
# 30         GERARD AVENUE             EAST 165 STREET
# 33       WILLIAMS AVENUE             ATLANTIC AVENUE
# 36       GRAND CONCOURSE             EAST 192 STREET
# 37              AVENUE Z                  SHELL ROAD
# 38         FOREST AVENUE             EAST 166 STREET
# 39      MANHATTAN AVENUE             WEST 110 STREET
# 40      EASTCHESTER ROAD                GIVAN AVENUE
# 41        CRESTON AVENUE       EAST KINGSBRIDGE ROAD
# 42       WEST 129 STREET                    5 AVENUE
# 43        WEST 30 STREET                    7 AVENUE
# 44        EAST 28 STREET             VOORHIES AVENUE
# 45     ST NICHOLAS PLACE          ST NICHOLAS AVENUE
# 46       EAST 105 STREET          FLATLANDS 2 STREET
# 48              AVENUE Z                  SHELL ROAD
# 50       WEST 151 STREET                    7 AVENUE
# 51              8 AVENUE                    3 STREET
# 52        LINCOLN AVENUE            MC KINLEY AVENUE
# 53       WEST 158 STREET            AMSTERDAM AVENUE
# 54         BAILEY AVENUE             WEST 238 STREET
# 58        EAST 17 STREET               DITMAS AVENUE
# 60        CONVENT AVENUE             WEST 128 STREET
# 61      CARPENTER AVENUE             EAST 230 STREET
# 62        EAST 82 STREET                    AVENUE K
# 63              8 AVENUE             WEST 129 STREET
# 64          ARDEN STREET                NAGLE AVENUE
# 65        EAST 36 STREET             FLATBUSH AVENUE
# 67         BAILEY AVENUE             WEST 238 STREET
# 68     CROTONA PARK EAST           CLAREMONT PARKWAY
# 70       EAST 128 STREET                 PARK AVENUE
# 71        BOYNTON AVENUE          BRUCKNER BOULEVARD
# 72       SCHAEFER STREET               WILSON AVENUE
#                      ...                         ...
#
#                Cross Street 2  Intersection Street 1  Intersection Street 2  \
# 0   MANHATTAN COLLEGE PARKWAY                    NaN                    NaN
# 1              PELHAM PARKWAY                    NaN                    NaN
# 2          PROSPECT PARK WEST                    NaN                    NaN
# 3               ALBANY AVENUE                    NaN                    NaN
# 4             WEST 204 STREET                    NaN                    NaN
# 5               THROOP AVENUE                    NaN                    NaN
# 6                        BEND                    NaN                    NaN
# 7            EVERGREEN AVENUE                    NaN                    NaN
# 8                        BEND                    NaN                    NaN
# 9         BEACH CHANNEL DRIVE                    NaN                    NaN
# 10                       BEND                    NaN                    NaN
# 11               OCEAN AVENUE                    NaN                    NaN
# 12             EAST 52 STREET                    NaN                    NaN
# 13            EAST 168 STREET                    NaN                    NaN
# 14            EAST 168 STREET                    NaN                    NaN
# 16              SUMMIT AVENUE                    NaN                    NaN
# 17                   31 DRIVE                    NaN                    NaN
# 18              FARRAGUT ROAD                    NaN                    NaN
# 19            STARLING AVENUE                    NaN                    NaN
# 20               UTICA AVENUE                    NaN                    NaN
# 21               ARNOW AVENUE                    NaN                    NaN
# 22                   AVENUE J                    NaN                    NaN
# 23                       BEND                    NaN                    NaN
# 24                BROWN PLACE                    NaN                    NaN
# 25          WADSWORTH TERRACE                    NaN                    NaN
# 26            WEST 177 STREET                    NaN                    NaN
# 27              ALBANY AVENUE                    NaN                    NaN
# 28           LEXINGTON AVENUE                    NaN                    NaN
# 29            EAST 201 STREET                    NaN                    NaN
# 30          MC CLELLAN STREET                    NaN                    NaN
# 33             LIBERTY AVENUE                    NaN                    NaN
# 36            EAST 193 STREET                    NaN                    NaN
# 37              WEST 3 STREET                    NaN                    NaN
# 38                HOME STREET                    NaN                    NaN
# 39            WEST 111 STREET                    NaN                    NaN
# 40           TILLOTSON AVENUE                    NaN                    NaN
# 41            EAST 196 STREET                    NaN                    NaN
# 42               LENOX AVENUE                    NaN                    NaN
# 43                   8 AVENUE                    NaN                    NaN
# 44               BELT PARKWAY                    NaN                    NaN
# 45            WEST 150 STREET                    NaN                    NaN
# 46                   AVENUE K                    NaN                    NaN
# 48              WEST 3 STREET                    NaN                    NaN
# 50              MACOMBS PLACE                    NaN                    NaN
# 51                   4 STREET                    NaN                    NaN
# 52             LIBERTY AVENUE                    NaN                    NaN
# 53                   BROADWAY                    NaN                    NaN
# 54                       BEND                    NaN                    NaN
# 58             NEWKIRK AVENUE                    NaN                    NaN
# 60            WEST 129 STREET                    NaN                    NaN
# 61            EAST 231 STREET                    NaN                    NaN
# 62                   AVENUE L                    NaN                    NaN
# 63            WEST 130 STREET                    NaN                    NaN
# 64             SHERMAN AVENUE                    NaN                    NaN
# 65                   AVENUE K                    NaN                    NaN
# 67                       BEND                    NaN                    NaN
# 68           CHARLOTTE STREET                    NaN                    NaN
# 70           LEXINGTON AVENUE                    NaN                    NaN
# 71              WATSON AVENUE                    NaN                    NaN
# 72       KNICKERBOCKER AVENUE                    NaN                    NaN
#                           ...                    ...                    ...
#
#    Address Type      City  Landmark  Facility Type  Status
# 0       ADDRESS     BRONX       NaN            NaN  Closed ...
# 1       ADDRESS     BRONX       NaN            NaN  Closed ...
# 2       ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 3       ADDRESS  BROOKLYN       NaN            NaN  Closed ...
# 4       ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 5       ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 6       ADDRESS     BRONX       NaN            NaN  Closed ...
# 7       ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 8       ADDRESS     BRONX       NaN            NaN  Closed ...
# 9       ADDRESS   Arverne       NaN            NaN    Open ...
# 10      ADDRESS     BRONX       NaN            NaN  Closed ...
# 11      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 12      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 13      ADDRESS     BRONX       NaN            NaN  Closed ...
# 14      ADDRESS     BRONX       NaN            NaN  Closed ...
# 16      ADDRESS     BRONX       NaN            NaN  Closed ...
# 17      ADDRESS   Astoria       NaN            NaN    Open ...
# 18      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 19      ADDRESS     BRONX       NaN            NaN  Closed ...
# 20      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 21      ADDRESS     BRONX       NaN            NaN  Closed ...
# 22      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 23      ADDRESS     BRONX       NaN            NaN  Closed ...
# 24      ADDRESS     BRONX       NaN            NaN    Open ...
# 25      ADDRESS  NEW YORK       NaN            NaN    Open ...
# 26      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 27      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 28      ADDRESS  NEW YORK       NaN            NaN    Open ...
# 29      ADDRESS     BRONX       NaN            NaN  Closed ...
# 30      ADDRESS     BRONX       NaN            NaN  Closed ...
# 33      ADDRESS  BROOKLYN       NaN            NaN  Closed ...
# 36      ADDRESS     BRONX       NaN            NaN    Open ...
# 37      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 38      ADDRESS     BRONX       NaN            NaN    Open ...
# 39      ADDRESS  NEW YORK       NaN            NaN    Open ...
# 40      ADDRESS     BRONX       NaN            NaN    Open ...
# 41      ADDRESS     BRONX       NaN            NaN  Closed ...
# 42      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 43      ADDRESS  NEW YORK       NaN            NaN    Open ...
# 44      ADDRESS  BROOKLYN       NaN            NaN  Closed ...
# 45      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 46      ADDRESS  BROOKLYN       NaN            NaN  Closed ...
# 48      ADDRESS  BROOKLYN       NaN            NaN  Closed ...
# 50      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 51      ADDRESS  BROOKLYN       NaN            NaN  Closed ...
# 52      ADDRESS  BROOKLYN       NaN            NaN  Closed ...
# 53      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 54      ADDRESS     BRONX       NaN            NaN  Closed ...
# 58      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 60      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 61      ADDRESS     BRONX       NaN            NaN    Open ...
# 62      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 63      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 64      ADDRESS  NEW YORK       NaN            NaN  Closed ...
# 65      ADDRESS  BROOKLYN       NaN            NaN    Open ...
# 67      ADDRESS     BRONX       NaN            NaN  Closed ...
# 68      ADDRESS     BRONX       NaN            NaN    Open ...
# 70      ADDRESS  NEW YORK       NaN            NaN    Open ...
# 71      ADDRESS     BRONX       NaN            NaN  Closed ...
# 72      ADDRESS  BROOKLYN       NaN            NaN    Open ...
#             ...       ...       ...            ...     ...
#
# [201781 rows x 52 columns]

# %%
#Let's see where the most complaints are located. Also a way to verify nothing got lost along the way. Still 67306 in the Bronx

HEAT["Borough"].value_counts()
# Out:
# BRONX            67306
# BROOKLYN         60721
# MANHATTAN        47118
# QUEENS           24774
# STATEN ISLAND     1862
# dtype: int64

# %%
#Let's look at the column names

HEAT.columns
# Out:
# Index([u'Unique Key', u'Created Date', u'Closed Date', u'Agency', u'Agency Name', u'Complaint Type', u'Descriptor', u'Location Type', u'Incident Zip', u'Incident Address', u'Street Name', u'Cross Street 1', u'Cross Street 2', u'Intersection Street 1', u'Intersection Street 2', u'Address Type', u'City', u'Landmark', u'Facility Type', u'Status', u'Due Date', u'Resolution Action Updated Date', u'Community Board', u'Borough', u'X Coordinate (State Plane)', u'Y Coordinate (State Plane)', u'Park Facility Name', u'Park Borough', u'School Name', u'School Number', u'School Region', u'School Code', u'School Phone Number', u'School Address', u'School City', u'School State', u'School Zip', u'School Not Found', u'School or Citywide Complaint', u'Vehicle Type', u'Taxi Company Borough', u'Taxi Pick Up Location', u'Bridge Highway Name', u'Bridge Highway Direction', u'Road Ramp', u'Bridge Highway Segment', u'Garage Lot Name', u'Ferry Direction', u'Ferry Terminal Name', u'Latitude', u'Longitude', u'Location'], dtype='object')

# %%
# I would like to look how long it took for the complaint to be settled in different parts of the city. Does it take longer in the Bronx?
# Let's subset the column containing information about when the complaint was filed

created_date = HEAT["Created Date"]

# %%
#Let's have a look. 

created_date.head()
# Out:
# 0    12/31/2013 12:00:00 AM
# 1    12/31/2013 12:00:00 AM
# 2    12/31/2013 12:00:00 AM
# 3    12/31/2013 12:00:00 AM
# 4    12/31/2013 12:00:00 AM
# Name: Created Date, dtype: object

# %%
#Let's convert it to a workable format

from pandas import to_datetime

# %%
created_dates = to_datetime(created_date,format='%m/%d/%Y %I:%M:%S %p',coerce=True)
created_dates.head()
# Out:
# 0   2013-12-31
# 1   2013-12-31
# 2   2013-12-31
# 3   2013-12-31
# 4   2013-12-31
# Name: Created Date, dtype: datetime64[ns]

# %%
#Let's do the same for the date at which the complaints were closed

closed_date = HEAT["Closed Date"]
closed_dates = to_datetime(closed_date,format='%m/%d/%Y %I:%M:%S %p',coerce=True)
closed_dates.head()
# Out:
# 0   2014-01-02
# 1   2013-12-31
# 2          NaT
# 3   2014-01-03
# 4   2014-01-03
# Name: Closed Date, dtype: datetime64[ns]

# %%
#Let's convert it to day of the year 

doy_created = created_dates.apply(lambda t: t.dayofyear)

# %%
#Let's have a look at the distribution.It would be interesting to plot this this against median temperatures. 
# It looks like the 24th and the 329th day of the year were particularly bad. 
# Indeed, the fourth week of January was particularly cold, with temperatures in the low 20s. 
# The second spike coincides with the last week of November, which had temperatures in the low 30s. 

doy_created.value_counts().sort_index().plot(figsize=[20,10])
vlines(24,0,6000)
vlines(329,0,6000)
show()

# %%
# Let's do the same for the close dates

doy_closed = closed_dates.apply(lambda t: t.dayofyear)

# %%
doy_closed.head()
# Out:
# 0      2
# 1    365
# 2     -1
# 3      3
# 4      3
# Name: Closed Date, dtype: int64

# %%
type(doy_created)
# Out:
# pandas.core.series.Series

# %%
doy_created[2]
# Out:
# 365

# %%
doy_created[23]
# Out:
# 365

# %%
#Let's look at the number of days it took for cases to be closed

for d in doy_created:
    length.append(int(doy_closed[d])-int(doy_created))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-665737ea0358> in <module>()
#       1 lenght=[]
#       2 for d in doy_created:
# ----> 3     length.append(int(doy_closed[d])-int(doy_created))
#
# NameError: name 'length' is not defined
